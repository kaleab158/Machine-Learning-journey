# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Analysise  And  Reporting
#
#
#  1.1 Analysis On Given_data
#    1.1.1 on User inserted_Data
#    1.1.2 On Given cvs file data
#    1.1.3 On web_linked cvs data
#
#
#
# 1.2 Reporting On Given Data
#   1.2.1 Reporting On User Inserted_Data
#   1.2.2 Reporting On Given Cvs file Data
#   1.2.3 Reporting On Web_Linked cvs Data

# %%
print("============================================")
print("================ Wellcome ==================")
print("============================================")
print("Enter Your Choise")
print("1 , Enter Cvs Data")
print("1 , Enter Cvs By File")
print("1 , Enter Cvs Data From Link ")
def Data_Insertion():
    if(x == 1){
  print("Enter Your Cvs Data")
    }
   elif(x == 2 ){
  print("Enter Your ")
   }
   elif(x == 3){
     
  }
def Data_Calculation():
def Data_Visualization():


x = int(input("Enter Your Choice: "))
if(x == 1){
    """   =   """
}
elif(x == 2 ){
    """ """
}
elif( x== 3 ){
    """ """
}
else{
    """  = """
}
# Out:
# ============================================
# ================ Wellcome ==================
# ============================================
# Enter Your Choise
